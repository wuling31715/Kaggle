# %% [markdown]
# # Part 2

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import csv
import datetime

# %%
pd.set_option('display.max_columns', None)

# %%
def load_data(i):
    i = str(i)
    train_data = pd.read_csv('/Users/dannyshau/.kaggle/competitions/introml2018p%s/introML2018.task%s.train.csv' % (i, i))
    test_data = pd.read_csv('/Users/dannyshau/.kaggle/competitions/introml2018p%s/introML2018.task%s.test.csv' % (i, i))
    return train_data, test_data

# %%
def standardization(series):
    from sklearn import preprocessing
    array = preprocessing.scale(series)
    series = pd.Series(array)
    return series

# %%
def normalization(series):
    from sklearn import preprocessing
    list = series.tolist()
    array = preprocessing.normalize([list])
    return pd.Series(array[0])

# %%
def transoform(data, function):
    df = pd.DataFrame()
    for i in range(data.shape[1]):
#     for i in range(0, 25):
        feature = 'feature_' + str(i)
        series = pd.DataFrame(function(data[feature]), columns=[feature])
        df = pd.concat([df, series], axis=1)
    return df

# %%
def classification(model):
    print(model)
    model.fit(x_train, y_train)
    print(model.score(x_train, y_train))
    y_model = model.predict(x_test)
    from sklearn.metrics import accuracy_score
    print(accuracy_score(y_test, y_model))
    return model

# %%
def predict(model):
    result = model.predict(test_data)
    time = datetime.datetime.now().strftime("%Y%m%d%H%M%S")
    path = 'results/' + time + '.csv'
    with open(path, 'w', newline='') as csvfile:
        fieldnames = ['ID', 'label']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for i, j in enumerate(result):
            writer.writerow({'ID': i+1, 'label': j})
    print(result.shape)
    return result

# %%
all_data = load_data(2)

# %%
train_data = all_data[0]
train_data.describe()
# Out:
#           feature_0     feature_1     feature_2     feature_3     feature_4  \
# count  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06
# mean   9.998887e-01  1.000103e+00  1.000169e+00  9.997087e-01  1.000705e+00
# std    5.775428e-01  5.772153e-01  5.772686e-01  5.773273e-01  5.773856e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    4.996900e-01  5.007300e-01  5.004100e-01  4.994800e-01  5.006500e-01
# 50%    9.996000e-01  9.998600e-01  9.999600e-01  9.994800e-01  1.001040e+00
# 75%    1.500190e+00  1.499890e+00  1.500300e+00  1.499280e+00  1.501030e+00
# max    2.000000e+00  2.000000e+00  2.000000e+00  2.000000e+00  2.000000e+00
#
#           feature_5     feature_6     feature_7     feature_8     feature_9  \
# count  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06
# mean   5.388051e-01  5.254977e-01  5.287605e-01  5.193667e-01  5.151161e-01
# std    4.591625e-01  4.436575e-01  4.460048e-01  4.427414e-01  4.414147e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.608900e-01  1.593200e-01  1.622000e-01  1.573800e-01  1.563800e-01
# 50%    4.112300e-01  4.104800e-01  4.124500e-01  3.978300e-01  3.912000e-01
# 75%    8.174100e-01  7.897200e-01  7.910400e-01  7.814700e-01  7.749400e-01
# max    3.427280e+00  3.806810e+00  3.546030e+00  3.235460e+00  3.416340e+00
#
#          feature_10    feature_11    feature_12    feature_13    feature_14  \
# count  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06
# mean   5.118846e-01  5.366713e-01  5.316039e-01  5.115791e-01  5.394357e-01
# std    4.464035e-01  4.567437e-01  4.561411e-01  4.443781e-01  4.466918e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.507000e-01  1.604200e-01  1.584300e-01  1.491800e-01  1.729600e-01
# 50%    3.832100e-01  4.109900e-01  4.056800e-01  3.842000e-01  4.254000e-01
# 75%    7.661500e-01  8.124300e-01  7.993400e-01  7.714600e-01  8.051900e-01
# max    3.619490e+00  3.448860e+00  3.355260e+00  3.453770e+00  3.407990e+00
#
#          feature_15    feature_16    feature_17    feature_18    feature_19  \
# count  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06
# mean   5.282864e-01  5.376295e-01  5.390382e-01  5.132777e-01  5.192905e-01
# std    4.472308e-01  4.530170e-01  4.570189e-01  4.396200e-01  4.478347e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.598200e-01  1.623200e-01  1.623800e-01  1.519100e-01  1.538300e-01
# 50%    4.091400e-01  4.147300e-01  4.132900e-01  3.935300e-01  3.962200e-01
# 75%    7.966900e-01  8.187600e-01  8.196600e-01  7.757900e-01  7.772900e-01
# max    3.634310e+00  3.359430e+00  3.571850e+00  3.526640e+00  3.346200e+00
#
#          feature_20    feature_21    feature_22    feature_23    feature_24  \
# count  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06
# mean   5.315256e-01  5.364249e-01  5.311811e-01  5.229958e-01  5.201064e-01
# std    4.553216e-01  4.488108e-01  4.545788e-01  4.473243e-01  4.458803e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.570000e-01  1.673600e-01  1.607200e-01  1.576800e-01  1.567100e-01
# 50%    4.063300e-01  4.167700e-01  4.043900e-01  3.994200e-01  3.957000e-01
# 75%    8.043800e-01  8.099100e-01  7.984400e-01  7.861900e-01  7.822000e-01
# max    3.404590e+00  3.548560e+00  4.120560e+00  3.597060e+00  3.839600e+00
#
#          feature_25         label
# count  4.000000e+06  4.000000e+06
# mean   5.273125e-01  2.000000e+00
# std    9.385347e-02  1.414214e+00
# min    1.597900e-01  0.000000e+00
# 25%    4.624200e-01  1.000000e+00
# 50%    5.239200e-01  2.000000e+00
# 75%    5.887900e-01  3.000000e+00
# max    1.048960e+00  4.000000e+00

# %%
x_data = train_data.drop(['label'] , axis=1)
y_data = train_data['label']
# x_data.describe()

# %%
x_data = transoform(x_data, standardization)
x_data.describe()
# Out:
#           feature_0     feature_1     feature_2     feature_3     feature_4  \
# count  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06
# mean   1.252301e-15  1.621297e-15  1.013063e-15  1.378548e-15  7.136243e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.731281e+00 -1.732635e+00 -1.732589e+00 -1.731615e+00 -1.733165e+00
# 25%   -8.660808e-01 -8.651422e-01 -8.657306e-01 -8.664561e-01 -8.660669e-01
# 50%   -4.998202e-04 -4.213399e-04 -3.620916e-04 -3.962190e-04  5.810366e-04
# 75%    8.662585e-01  8.658587e-01  8.663750e-01  8.653173e-01  8.665362e-01
# max    1.731666e+00  1.732277e+00  1.732003e+00  1.732624e+00  1.730725e+00
#
#           feature_5     feature_6     feature_7     feature_8     feature_9  \
# count  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06
# mean   8.574261e-16 -1.508624e-16  4.374670e-16 -7.509158e-16 -1.797389e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.173452e+00 -1.184467e+00 -1.185549e+00 -1.173070e+00 -1.166966e+00
# 25%   -8.230532e-01 -8.253614e-01 -8.218757e-01 -8.176030e-01 -8.126963e-01
# 50%   -2.778431e-01 -2.592489e-01 -2.607830e-01 -2.745094e-01 -2.807248e-01
# 75%    6.067675e-01  5.955548e-01  5.880645e-01  5.920010e-01  5.886165e-01
# max    6.290747e+00  7.396050e+00  6.765106e+00  6.134718e+00  6.572560e+00
#
#          feature_10    feature_11    feature_12    feature_13    feature_14  \
# count  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06
# mean  -4.052936e-16  6.036203e-16 -9.487167e-16 -3.467449e-17  8.773782e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.146686e+00 -1.174994e+00 -1.165438e+00 -1.151225e+00 -1.207624e+00
# 25%   -8.090991e-01 -8.237691e-01 -8.181107e-01 -8.155198e-01 -8.204220e-01
# 50%   -2.882474e-01 -2.751682e-01 -2.760635e-01 -2.866459e-01 -2.552895e-01
# 75%    5.695865e-01  6.037493e-01  5.869591e-01  5.848192e-01  5.949389e-01
# max    6.961428e+00  6.375980e+00  6.190314e+00  6.620918e+00  6.421776e+00
#
#          feature_15    feature_16    feature_17    feature_18    feature_19  \
# count  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06
# mean   2.696652e-16 -1.505725e-15  2.632419e-16 -4.680487e-16 -4.207550e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.181239e+00 -1.186776e+00 -1.179466e+00 -1.167549e+00 -1.159558e+00
# 25%   -8.238844e-01 -8.284668e-01 -8.241634e-01 -8.220003e-01 -8.160611e-01
# 50%   -2.664093e-01 -2.712911e-01 -2.751488e-01 -2.723891e-01 -2.748123e-01
# 75%    6.001456e-01  6.205740e-01  6.140268e-01  5.971348e-01  5.761044e-01
# max    6.945014e+00  6.228907e+00  6.636076e+00  6.854472e+00  6.312395e+00
#
#          feature_20    feature_21    feature_22    feature_23    feature_24  \
# count  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06
# mean  -2.531806e-16  1.157900e-16 -4.160938e-17  7.871392e-16  6.815526e-17
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.167363e+00 -1.195214e+00 -1.168513e+00 -1.169165e+00 -1.166471e+00
# 25%   -8.225518e-01 -8.223174e-01 -8.149548e-01 -8.166691e-01 -8.150090e-01
# 50%   -2.749607e-01 -2.666043e-01 -2.789201e-01 -2.762557e-01 -2.790130e-01
# 75%    5.992566e-01  6.093552e-01  5.879264e-01  5.883745e-01  5.878117e-01
# max    6.309968e+00  6.711371e+00  7.896055e+00  6.872117e+00  7.444810e+00
#
#          feature_25
# count  4.000000e+06
# mean  -4.596501e-16
# std    1.000000e+00
# min   -3.915919e+00
# 25%   -6.914240e-01
# 50%   -3.614716e-02
# 75%    6.550367e-01
# max    5.558106e+00

# %%
test_data = all_data[1]
test_data.describe()
# Out:
#             feature_0       feature_1       feature_2       feature_3  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         0.999743        0.999875        0.999481        0.999169
# std          0.577073        0.577130        0.576957        0.577243
# min          0.000000        0.000000        0.000000        0.000000
# 25%          0.500830        0.500390        0.499940        0.499010
# 50%          0.999620        0.999300        0.999460        0.999580
# 75%          1.500153        1.499620        1.498400        1.498492
# max          2.000000        2.000000        2.000000        2.000000
#
#             feature_4       feature_5       feature_6       feature_7  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         0.999777        0.539082        0.525651        0.528999
# std          0.577248        0.458793        0.443609        0.446418
# min          0.000000        0.000000        0.000000        0.000000
# 25%          0.499560        0.161200        0.159370        0.161790
# 50%          1.000010        0.412410        0.410760        0.412980
# 75%          1.499760        0.817160        0.791070        0.791580
# max          2.000000        3.616130        3.440780        3.300150
#
#             feature_8       feature_9      feature_10      feature_11  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         0.520119        0.515319        0.511802        0.536765
# std          0.443107        0.441788        0.446646        0.457255
# min          0.000000        0.000000        0.000000        0.000000
# 25%          0.157730        0.156280        0.150560        0.160150
# 50%          0.398670        0.390830        0.382800        0.410790
# 75%          0.782210        0.775540        0.765910        0.812500
# max          3.110740        3.372110        3.070270        3.345030
#
#            feature_12      feature_13      feature_14      feature_15  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         0.532216        0.511126        0.540107        0.527125
# std          0.456827        0.443906        0.447182        0.446390
# min          0.000000        0.000000        0.000000        0.000000
# 25%          0.158260        0.149150        0.173320        0.159587
# 50%          0.406390        0.383930        0.425600        0.408120
# 75%          0.799520        0.770522        0.806560        0.794292
# max          3.219440        3.073260        3.172190        3.485500
#
#            feature_16      feature_17      feature_18      feature_19  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         0.537072        0.539120        0.512914        0.519204
# std          0.452627        0.457101        0.439464        0.447696
# min          0.000000        0.000000        0.000000        0.000000
# 25%          0.162300        0.162300        0.151540        0.153790
# 50%          0.414280        0.413080        0.392725        0.396410
# 75%          0.817153        0.819870        0.775980        0.776640
# max          3.270400        3.631180        3.241230        3.146300
#
#            feature_20      feature_21      feature_22      feature_23  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         0.530890        0.536497        0.530859        0.522787
# std          0.454723        0.449147        0.454260        0.446792
# min          0.000000        0.000000        0.000000        0.000000
# 25%          0.156620        0.167090        0.161060        0.157960
# 50%          0.405860        0.416860        0.404240        0.399700
# 75%          0.803470        0.810350        0.797420        0.785870
# max          3.273260        3.214920        3.157650        3.558480
#
#            feature_24      feature_25
# count  1000000.000000  1000000.000000
# mean         0.520502        0.527302
# std          0.446636        0.093785
# min          0.000000        0.162850
# 25%          0.156200        0.462350
# 50%          0.395740        0.523940
# 75%          0.782970        0.588800
# max          3.090600        1.060870

# %%
test_data = transoform(test_data, standardization)
test_data.describe()
# Out:
#           feature_0     feature_1     feature_2     feature_3     feature_4  \
# count  1.000000e+06  1.000000e+06  1.000000e+06  1.000000e+06  1.000000e+06
# mean  -3.524292e-17  7.000107e-16 -3.106706e-16  6.682193e-16  7.202487e-16
# std    1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min   -1.732437e+00 -1.732496e+00 -1.732335e+00 -1.730933e+00 -1.731971e+00
# 25%   -8.645570e-01 -8.654633e-01 -8.658217e-01 -8.664621e-01 -8.665551e-01
# 50%   -2.123371e-04 -9.954654e-04 -3.681662e-05  7.115570e-04  4.030139e-04
# 75%    8.671519e-01  8.659155e-01  8.647428e-01  8.650138e-01  8.661485e-01
# max    1.733329e+00  1.732930e+00  1.734133e+00  1.733812e+00  1.732743e+00
#
#           feature_5     feature_6     feature_7     feature_8     feature_9  \
# count  1.000000e+06  1.000000e+06  1.000000e+06  1.000000e+06  1.000000e+06
# mean   5.710810e-16 -3.297735e-16 -4.706493e-16 -5.051959e-16 -2.205027e-16
# std    1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min   -1.175001e+00 -1.184942e+00 -1.184985e+00 -1.173800e+00 -1.166441e+00
# 25%   -8.236440e-01 -8.256843e-01 -8.225666e-01 -8.178369e-01 -8.126960e-01
# 50%   -2.760986e-01 -2.589914e-01 -2.598880e-01 -2.740858e-01 -2.817848e-01
# 75%    6.061074e-01  5.983179e-01  5.881956e-01  5.914835e-01  5.890181e-01
# max    6.706832e+00  6.571395e+00  6.207522e+00  5.846488e+00  6.466434e+00
#
#          feature_10    feature_11    feature_12    feature_13    feature_14  \
# count  1.000000e+06  1.000000e+06  1.000000e+06  1.000000e+06  1.000000e+06
# mean   1.770495e-16 -4.518341e-17 -4.203446e-16 -4.543939e-16 -1.272795e-16
# std    1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min   -1.145880e+00 -1.173886e+00 -1.165029e+00 -1.151427e+00 -1.207803e+00
# 25%   -8.087896e-01 -8.236434e-01 -8.185954e-01 -8.154329e-01 -8.202198e-01
# 50%   -2.888247e-01 -2.755022e-01 -2.754354e-01 -2.865371e-01 -2.560645e-01
# 75%    5.689250e-01  6.030239e-01  5.851317e-01  5.843510e-01  5.958484e-01
# max    5.728184e+00  6.141581e+00  5.882370e+00  5.771795e+00  5.885933e+00
#
#          feature_15    feature_16    feature_17    feature_18    feature_19  \
# count  1.000000e+06  1.000000e+06  1.000000e+06  1.000000e+06  1.000000e+06
# mean  -8.686030e-17  4.898517e-16 -4.550920e-16 -1.094236e-18 -3.423768e-16
# std    1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min   -1.180862e+00 -1.186566e+00 -1.179432e+00 -1.167134e+00 -1.159726e+00
# 25%   -8.233549e-01 -8.279927e-01 -8.243685e-01 -8.223051e-01 -8.162113e-01
# 50%   -2.665935e-01 -2.712872e-01 -2.757372e-01 -2.734890e-01 -2.742805e-01
# 75%    5.985085e-01  6.187886e-01  6.141972e-01  5.986073e-01  5.750244e-01
# max    6.627340e+00  6.038807e+00  6.764499e+00  6.208281e+00  5.868041e+00
#
#          feature_20    feature_21    feature_22    feature_23    feature_24  \
# count  1.000000e+06  1.000000e+06  1.000000e+06  1.000000e+06  1.000000e+06
# mean   2.628440e-16  2.925518e-16  4.255671e-16  8.630963e-17  2.714273e-17
# std    1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min   -1.167502e+00 -1.194480e+00 -1.168624e+00 -1.170091e+00 -1.165384e+00
# 25%   -8.230724e-01 -8.224634e-01 -8.140698e-01 -8.165483e-01 -8.156581e-01
# 50%   -2.749581e-01 -2.663642e-01 -2.787377e-01 -2.754914e-01 -2.793371e-01
# 75%    5.994429e-01  6.097196e-01  5.868016e-01  5.888255e-01  5.876563e-01
# max    6.030863e+00  5.963362e+00  5.782569e+00  6.794418e+00  5.754353e+00
#
#          feature_25
# count  1.000000e+06
# mean   2.150861e-15
# std    1.000001e+00
# min   -3.886046e+00
# 25%   -6.925621e-01
# 50%   -3.584544e-02
# 75%    6.557383e-01
# max    5.689287e+00

# %%
from sklearn.utils import shuffle
x_data, y_data = shuffle(x_data, y_data)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (3000000, 26)
# (1000000, 26)
# (3000000,)
# (1000000,)

# %%
# %%time
from sklearn.naive_bayes import GaussianNB
model = classification(GaussianNB())
result = predict(model)
# Out:
# GaussianNB(priors=None)
# 0.261708
# 0.261484
# CPU times: user 18.6 s, sys: 22 s, total: 40.6 s
# Wall time: 1min 5s

# %%
# %%time
# from sklearn import tree
# model = classification(tree.DecisionTreeClassifier())
# result = predict(model)

# %%
# %%time
# from sklearn.neighbors import KNeighborsClassifier
# model = classification(KNeighborsClassifier())
# result = predict(model)

# %%
# %%time
# from sklearn.linear_model import LogisticRegression
# model = classification(LogisticRegression())
# result = predict(model)

# %%
# %%time
# from sklearn import svm
# model = classification(svm.SVC())
# result = predict(model)

# %%
# %%time
# from sklearn.neural_network import MLPClassifier
# model = classification(MLPClassifier())
# result = predict(model)

# %%
# %%time
# from sklearn.ensemble import AdaBoostClassifier
# model = classification(AdaBoostClassifier())
# result = predict(model)

# %%
# %%time
# from sklearn.ensemble import GradientBoostingClassifier
# model = classification(GradientBoostingClassifier())
# result = predict(model)

# %%
# %%time
# from xgboost import XGBClassifier
# model = classification(XGBClassifier(n_estimators=100))
# result = predict(model)

# %%
# %%time
from sklearn.ensemble import RandomForestClassifier
model = classification(RandomForestClassifier(n_estimators=100))
result = predict(model)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# 1.0
# 0.707861
# CPU times: user 1h 30min 46s, sys: 3min 55s, total: 1h 34min 42s
# Wall time: 1h 42min 58s

# %%
# %%time
from sklearn.ensemble import RandomForestClassifier
model = classification(RandomForestClassifier(n_estimators=100))
result = predict(model)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# 1.0
# 0.709209
# CPU times: user 1h 33min 42s, sys: 5min 29s, total: 1h 39min 12s
# Wall time: 1h 52min 3s

# %%
# %%time
from sklearn.ensemble import RandomForestClassifier
model = classification(RandomForestClassifier(n_estimators=120))
result = predict(model)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=120, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# 1.0
# 0.715058
# CPU times: user 1h 41min 6s, sys: 3min 24s, total: 1h 44min 30s
# Wall time: 1h 49min 34s

# %%
# %%time
from sklearn.ensemble import RandomForestClassifier
model = classification(RandomForestClassifier(n_estimators=120))
result = predict(model)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=120, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# 1.0
# 0.714948
# (1000000,)
# CPU times: user 1h 57min 30s, sys: 4min 54s, total: 2h 2min 25s
# Wall time: 2h 12min 1s
