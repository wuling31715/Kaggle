# %% [markdown]
# # Part 2

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import csv

# %%
def load_data(i):
    i = str(i)
    train_data = pd.read_csv('/Users/dannyshau/.kaggle/competitions/introml2018p%s/introML2018.task%s.train.csv' % (i, i))
    test_data = pd.read_csv('/Users/dannyshau/.kaggle/competitions/introml2018p%s/introML2018.task%s.test.csv' % (i, i))
    return train_data, test_data

# %%
def standardization(series):
    from sklearn import preprocessing
    array = preprocessing.scale(series)
    series = pd.Series(array)
    return series

# %%
def normalization(series):
    from sklearn import preprocessing
    list = series.tolist()
    array = preprocessing.normalize([list])
    return pd.Series(array[0])

# %%
def transoform(data, function):
    df = pd.DataFrame()
    for i in range(data.shape[1]):
        feature = 'feature_' + str(i)
        series = pd.DataFrame(function(data[feature]), columns=[feature])
        df = pd.concat([df, series], axis=1)
    return df

# %%
def classification(model):
    print(model)
    model.fit(x_train, y_train)
    print(model.score(x_train, y_train))
    y_model = model.predict(x_test)
    from sklearn.metrics import accuracy_score
    print(accuracy_score(y_test, y_model))
    return model

# %%
def predict(model):
    result = model.predict(test_data)
    file_name = 'result.csv'
    with open(file_name, 'w', newline='') as csvfile:
        fieldnames = ['ID', 'label']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for i, j in enumerate(result):
            writer.writerow({'ID': i+1, 'label': j})
    return result

# %%
all_data = load_data(2)

# %%
train_data = all_data[0]
train_data.describe()
# Out:
#           feature_0     feature_1     feature_2     feature_3     feature_4  \
# count  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06
# mean   9.998887e-01  1.000103e+00  1.000169e+00  9.997087e-01  1.000705e+00
# std    5.775428e-01  5.772153e-01  5.772686e-01  5.773273e-01  5.773856e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    4.996900e-01  5.007300e-01  5.004100e-01  4.994800e-01  5.006500e-01
# 50%    9.996000e-01  9.998600e-01  9.999600e-01  9.994800e-01  1.001040e+00
# 75%    1.500190e+00  1.499890e+00  1.500300e+00  1.499280e+00  1.501030e+00
# max    2.000000e+00  2.000000e+00  2.000000e+00  2.000000e+00  2.000000e+00
#
#           feature_5     feature_6     feature_7     feature_8     feature_9  \
# count  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06
# mean   5.388051e-01  5.254977e-01  5.287605e-01  5.193667e-01  5.151161e-01
# std    4.591625e-01  4.436575e-01  4.460048e-01  4.427414e-01  4.414147e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.608900e-01  1.593200e-01  1.622000e-01  1.573800e-01  1.563800e-01
# 50%    4.112300e-01  4.104800e-01  4.124500e-01  3.978300e-01  3.912000e-01
# 75%    8.174100e-01  7.897200e-01  7.910400e-01  7.814700e-01  7.749400e-01
# max    3.427280e+00  3.806810e+00  3.546030e+00  3.235460e+00  3.416340e+00
#
#          feature_10    feature_11    feature_12    feature_13    feature_14  \
# count  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06
# mean   5.118846e-01  5.366713e-01  5.316039e-01  5.115791e-01  5.394357e-01
# std    4.464035e-01  4.567437e-01  4.561411e-01  4.443781e-01  4.466918e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.507000e-01  1.604200e-01  1.584300e-01  1.491800e-01  1.729600e-01
# 50%    3.832100e-01  4.109900e-01  4.056800e-01  3.842000e-01  4.254000e-01
# 75%    7.661500e-01  8.124300e-01  7.993400e-01  7.714600e-01  8.051900e-01
# max    3.619490e+00  3.448860e+00  3.355260e+00  3.453770e+00  3.407990e+00
#
#          feature_15    feature_16    feature_17    feature_18    feature_19  \
# count  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06
# mean   5
# min          0.000000        0.000000        0.000000        0.000000
# 25%          0.156620        0.167090        0.161060        0.157960
# 50%          0.405860        0.416860        0.404240        0.399700
# 75%          0.803470        0.810350        0.797420        0.785870
# max          3.273260        3.214920        3.157650        3.558480
#
#            feature_24      feature_25
# count  1000000.000000  1000000.000000
# mean         0.520502        0.527302
# std          0.446636        0.093785
# min          0.000000        0.162850
# 25%          0.156200        0.462350
# 50%          0.395740        0.523940
# 75%          0.782970        0.588800
# max          3.090600        1.060870

# %%
test_data = transoform(test_data, normalization)
test_data.describe()
# Out:
#             feature_0       feature_1       feature_2       feature_3  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         0.000866        0.000866        0.000866        0.000866
# std          0.000500        0.000500        0.000500        0.000500
# min          0.000000        0.000000        0.000000        0.000000
# 25%          0.000434        0.000433        0.000433        0.000432
# 50%          0.000866        0.000866        0.000866        0.000866
# 75%          0.001300        0.001299        0.001298        0.001299
# max          0.001733        0.001732        0.001733        0.001733
#
#             feature_4       feature_5       feature_6       feature_7  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         0.000866        0.000762        0.000764        0.000764
# std          0.000500        0.000648        0.000645        0.000645
# min          0.000000        0.000000        0.000000        0.000000
# 25%          0.000433        0.000228        0.000232        0.000234
# 50%          0.000866        0.000583        0.000597        0.000597
# 75%          0.001299        0.001154        0.001150        0.001144
# max          0.001732        0.005108        0.005002        0.004768
#
#             feature_8       feature_9       ...            feature_16  \
# count  1000000.000000  1000000.000000       ...        1000000.000000
# mean         0.000761        0.000759       ...              0.000765
# std          0.000649        0.000651       ...              0.000644
# min          0.000000        0.000000       ...              0.000000
# 25%          0.000231        0.000230       ...              0.000231
# 50%          0.000583        0.000576       ...              0.000590
# 75%          0.001145        0.001143       ...              0.001163
# max          0.004553        0.004968       ...              0.004656
#
#            feature_17      feature_18      feature_19      feature_20  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         0.000763        0.000759        0.000757        0.000759
# std          0.000647        0.000651        0.000653        0.000651
# min          0.000000        0.000000        0.000000        0.000000
# 25%          0.000230        0.000224        0.000224        0.000224
# 50%          0.000584        0.000581        0.000578        0.000581
# 75%          0.001160        0.001149        0.001133        0.001149
# max          0.005137        0.004799        0.004589        0.004683
#
#            feature_21      feature_22      feature_23      feature_24  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         0.000767        0.000760        0.000760        0.000759
# std          0.000642        0.000650        0.000650        0.000651
# min          0.000000        0.000000        0.000000        0.000000
# 25%          0.000239        0.000231        0.000230        0.000228
# 50%          0.000596        0.000579        0.000581        0.000577
# 75%          0.001158        0.001141        0.001143        0.001142
# max          0.004595        0.004519        0.005174        0.004506
#
#            feature_25
# count  1000000.000000
# mean         0.000985
# std          0.000175
# min          0.000304
# 25%          0.000863
# 50%          0.000978
# 75%          0.001099
# max          0.001981
#
# [8 rows x 26 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (3000000, 25)
# (1000000, 25)
# (3000000,)
# (1000000,)

# %%
# %%time
from sklearn.naive_bayes import GaussianNB
model = classification(GaussianNB())
result = predict(model)
# Out:
# GaussianNB(priors=None)
# 0.259898
# 0.259869
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed exec> in <module>()
#
# <ipython-input-7-f29a84846f69> in predict(model)
#       1 def predict(model):
# ----> 2     result = model.predict(test_data)
#       3     file_name = 'result.csv'
#       4     with open(file_name, 'w', newline='') as csvfile:
#       5         fieldnames = ['ID', 'label']
#
# NameError: name 'test_data' is not defined

# %%
# %%time
from sklearn.naive_bayes import GaussianNB
model = classification(GaussianNB())
result = predict(model)
# Out:
# GaussianNB(priors=None)
# 0.2597116666666667
# 0.259499
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <timed exec> in <module>()
#
# <ipython-input-7-f29a84846f69> in predict(model)
#       1 def predict(model):
# ----> 2     result = model.predict(test_data)
#       3     file_name = 'result.csv'
#       4     with open(file_name, 'w', newline='') as csvfile:
#       5         fieldnames = ['ID', 'label']
#
# /Users/DannyShau/anaconda/envs/py3.5/lib/python3.5/site-packages/sklearn/naive_bayes.py in predict(self, X)
#      64             Predicted target values for X
#      65         """
# ---> 66         jll = self._joint_log_likelihood(X)
#      67         return self.classes_[np.argmax(jll, axis=1)]
#      68
#
# /Users/DannyShau/anaconda/envs/py3.5/lib/python3.5/site-packages/sklearn/naive_bayes.py in _joint_log_likelihood(self, X)
#     431             jointi = np.log(self.class_prior_[i])
#     432             n_ij = - 0.5 * np.sum(np.log(2. * np.pi * self.sigma_[i, :]))
# --> 433             n_ij -= 0.5 * np.sum(((X - self.theta_[i, :]) ** 2) /
#     434                                  (self.sigma_[i, :]), 1)
#     435             joint_log_likelihood.append(jointi + n_ij)
#
# ValueError: operands could not be broadcast together with shapes (1000000,26) (25,)

# %%
# %%time
from sklearn.naive_bayes import GaussianNB
model = classification(GaussianNB())
# result = predict(model)
# Out:
# GaussianNB(priors=None)
# 0.259979
# 0.259227
# CPU times: user 16.3 s, sys: 37.4 s, total: 53.7 s
# Wall time: 2min 19s

# %%
# %%time
from sklearn.naive_bayes import GaussianNB
model = classification(GaussianNB())
# result = predict(model)
# Out:
# GaussianNB(priors=None)
# 0.259979
# 0.259227
# CPU times: user 13.8 s, sys: 29.1 s, total: 42.9 s
# Wall time: 1min 42s

# %%
# %%time
from sklearn import tree
model = classification(tree.DecisionTreeClassifier())
result = predict(model)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# 1.0
# 0.422566

# %%
# %%time
from sklearn.neighbors import KNeighborsClassifier
model = classification(KNeighborsClassifier())
result = predict(model)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
# %%time
from sklearn.linear_model import LogisticRegression
model = classification(LogisticRegression())
result = predict(model)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# 0.9998462222222222
# 0.9998506666666667
# CPU times: user 1min 3s, sys: 2.82 s, total: 1min 6s
# Wall time: 1min 11s

# %%
# %%time
from sklearn import svm
model = classification(svm.SVC())
result = predict(model)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
# %%time
from sklearn.neural_network import MLPClassifier
model = classification(MLPClassifier())
result = predict(model)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# 0.999877333333
# 0.999869333333

# %%
# %%time
from sklearn.ensemble import AdaBoostClassifier
model = classification(AdaBoostClassifier())
result = predict(model)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#           learning_rate=1.0, n_estimators=50, random_state=None)
# 0.999210666667
# 0.999178666667

# %%
# %%time
from sklearn.ensemble import GradientBoostingClassifier
model = classification(GradientBoostingClassifier())
result = predict(model)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=None, subsample=1.0, verbose=0,
#               warm_start=False)

# %%
# %%time
from sklearn.ensemble import RandomForestClassifier
model = classification(RandomForestClassifier(n_estimators=100))
result = predict(model)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# 1.0
# 0.708051
# CPU times: user 1h 41min 13s, sys: 4min 26s, total: 1h 45min 39s
# Wall time: 1h 55min 53s

# %%
# %%time
from xgboost import XGBClassifier
model = classification(XGBClassifier(n_estimators=100))
result = predict(model)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)
# /Users/DannyShau/anaconda/envs/py3.5/lib/python3.5/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# 0.32543833333333333
# /Users/DannyShau/anaconda/envs/py3.5/lib/python3.5/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# 0.323587
# /Users/DannyShau/anaconda/envs/py3.5/lib/python3.5/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# CPU times: user 1h 40min 18s, sys: 12min 44s, total: 1h 53min 2s
# Wall time: 2h 22min 12s

# %%
# %%time
from sklearn.ensemble import RandomForestClassifier
model = classification(RandomForestClassifier(n_estimators=200))
result = predict(model)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# 0.34345033333333336
# 0.260638
# CPU times: user 2h 7min 36s, sys: 3min 5s, total: 2h 10min 41s
# Wall time: 2h 19min 22s
