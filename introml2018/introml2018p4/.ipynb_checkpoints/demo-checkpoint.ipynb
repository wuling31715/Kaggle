# %% [markdown]
# # Part 4

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import csv
import datetime

# %%
pd.set_option('display.max_columns', None)

# %%
def load_data(i):
    i = str(i)
    train_data = pd.read_csv('/Users/dannyshau/.kaggle/competitions/introml2018p%s/introML2018.task%s.train.csv' % (i, i))
    test_data = pd.read_csv('/Users/dannyshau/.kaggle/competitions/introml2018p%s/introML2018.task%s.test.csv' % (i, i))
    return train_data, test_data

# %%
def standardization(series):
    from sklearn import preprocessing
    array = preprocessing.scale(series)
    series = pd.Series(array)
    return series

# %%
def normalization(series):
    from sklearn import preprocessing
    list = series.tolist()
    array = preprocessing.normalize([list])
    return pd.Series(array[0])

# %%
def transoform(data, function):
    df = pd.DataFrame()
    for i in range(data.shape[1]):
        feature = 'feature_' + str(i)
        series = pd.DataFrame(function(data[feature]), columns=[feature])
        df = pd.concat([df, series], axis=1)
    return df

# %%
def classification(model):
    print(model)
    model.fit(x_train, y_train)
    print(model.score(x_train, y_train))
    y_model = model.predict(x_test)
    from sklearn.metrics import accuracy_score
    print(accuracy_score(y_test, y_model))
    return model

# %%
def predict(model):
    result = model.predict(test_data)
    time = datetime.datetime.now().strftime("%Y%m%d%H%M%S")
    path = 'results/' + time + '.csv'
    with open(path, 'w', newline='') as csvfile:
        fieldnames = ['ID', 'label']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for i, j in enumerate(result):
            writer.writerow({'ID': i+1, 'label': j})
    print(result.shape)
    return result

# %%
all_data = load_data(4)

# %%
train_data = all_data[0]
train_data.describe()
# Out:
#           feature_0     feature_1     feature_2     feature_3     feature_4  \
# count  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06
# mean   2.329976e+01  2.328899e+01  2.329538e+01  2.329390e+01  2.329427e+01
# std    2.213177e+01  2.210958e+01  2.212235e+01  2.213241e+01  2.212255e+01
# min   -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00
# 25%    5.076585e+00  5.091460e+00  5.078750e+00  5.074020e+00  5.081758e+00
# 50%    1.671772e+01  1.671697e+01  1.671802e+01  1.670476e+01  1.671282e+01
# 75%    3.641869e+01  3.638653e+01  3.642706e+01  3.641291e+01  3.641761e+01
# max    9.899954e+01  9.899643e+01  9.899943e+01  9.899933e+01  9.899009e+01
#
#           feature_5     feature_6     feature_7     feature_8     feature_9  \
# count  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06
# mean   4.510180e+00  4.738221e+00  4.518186e+00  4.344104e+00  4.508001e+00
# std    4.570341e+00  4.734311e+00  4.613511e+00  4.481322e+00  4.592540e+00
# min   -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00
# 25%    8.838100e-01  9.327000e-01  8.504575e-01  8.417900e-01  8.204375e-01
# 50%    3.257500e+00  3.451075e+00  3.201040e+00  3.050810e+00  3.217610e+00
# 75%    7.185233e+00  7.630920e+00  7.278750e+00  6.905123e+00  7.298055e+00
# max    3.795792e+01  3.357029e+01  3.504167e+01  3.157594e+01  3.162702e+01
#
#          feature_10    feature_11    feature_12    feature_13    feature_14  \
# count  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06
# mean   4.482112e+00  4.520323e+00  4.343939e+00  4.311408e+00  4.386485e+00
# std    4.545638e+00  4.577785e+00  4.450184e+00  4.463014e+00  4.505245e+00
# min   -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00
# 25%    8.947400e-01  9.014000e-01  8.799200e-01  7.834475e-01  8.529875e-01
# 50%    3.205035e+00  3.254310e+00  3.092070e+00  3.059560e+00  3.146430e+00
# 75%    7.173670e+00  7.198420e+00  6.870273e+00  6.862483e+00  6.920772e+00
# max    3.592316e+01  3.262604e+01  3.631962e+01  3.749833e+01  3.343654e+01
#
#          feature_15    feature_16    feature_17    feature_18    feature_19  \
# count  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06
# mean   4.447487e+00  4.474258e+00  4.454523e+00  4.480261e+00  4.434131e+00
# std    4.533379e+00  4.498260e+00  4.518280e+00  4.566692e+00  4.535719e+00
# min   -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00
# 25%    8.921500e-01  9.051900e-01  8.607475e-01  8.478500e-01  8.600100e-01
# 50%    3.199340e+00  3.263295e+00  3.224400e+00  3.213385e+00  3.168685e+00
# 75%    7.037600e+00  7.156392e+00  7.123370e+00  7.172623e+00  7.028650e+00
# max    3.241403e+01  3.577462e+01  3.452895e+01  3.306791e+01  3.459009e+01
#
#          feature_20    feature_21    feature_22    feature_23    feature_24  \
# count  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06
# mean   4.375295e+00  4.530716e+00  4.436475e+00  4.541590e+00  4.533463e+00
# std    4.508294e+00  4.568689e+00  4.564833e+00  4.606170e+00  4.579382e+00
# min   -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00
# 25%    8.162100e-01  9.213275e-01  8.216800e-01  9.004700e-01  9.201500e-01
# 50%    3.088990e+00  3.268715e+00  3.148210e+00  3.293470e+00  3.278720e+00
# 75%    7.005002e+00  7.244992e+00  7.071010e+00  7.203563e+00  7.190622e+00
# max    3.117587e+01  3.672234e+01  3.223187e+01  3.407382e+01  3.528180e+01
#
#          feature_25         label
# count  4.000000e+06  4.000000e+06
# mean   4.659642e+00  2.000000e+00
# std    1.704799e+00  1.414214e+00
# min   -1.000000e+00  0.000000e+00
# 25%    4.210300e+00  1.000000e+00
# 50%    4.919450e+00  2.000000e+00
# 75%    5.605110e+00  3.000000e+00
# max    1.091404e+01  4.000000e+00

# %%
x_data = train_data.drop('label', axis=1)
y_data = train_data['label']
# x_data.describe()

# %%
# x_data = transoform(x_data, standardization)
# x_data.describe()

# %%
test_data = all_data[1]
test_data.describe()
# Out:
#             feature_0       feature_1       feature_2       feature_3  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean        23.289610       23.262037       23.298565       23.269918
# std         22.125460       22.109636       22.122610       22.109248
# min         -1.000000       -1.000000       -1.000000       -1.000000
# 25%          5.071845        5.053038        5.073400        5.086877
# 50%         16.712540       16.692915       16.705225       16.706380
# 75%         36.394143       36.332370       36.418498       36.327438
# max         98.981560       98.992530       98.995910       98.963740
#
#             feature_4       feature_5       feature_6       feature_7  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean        23.252543        4.518221        4.737195        4.518344
# std         22.112905        4.576240        4.731782        4.611272
# min         -1.000000       -1.000000       -1.000000       -1.000000
# 25%          5.038647        0.883208        0.935600        0.847307
# 50%         16.679175        3.262375        3.446745        3.203825
# 75%         36.352072        7.204607        7.626030        7.280295
# max         98.996080       32.925760       33.432490       29.762470
#
#             feature_8       feature_9      feature_10      feature_11  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         4.340985        4.506140        4.481060        4.524522
# std          4.476575        4.590643        4.547326        4.581044
# min         -1.000000       -1.000000       -1.000000       -1.000000
# 25%          0.842718        0.820660        0.894530        0.897957
# 50%          3.047440        3.215020        3.200680        3.257760
# 75%          6.902988        7.297338        7.166040        7.209880
# max         30.670680       30.016310       28.899140       32.821940
#
#            feature_12      feature_13      feature_14      feature_15  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         4.345458        4.314790        4.387044        4.445423
# std          4.451755        4.464630        4.501614        4.530862
# min         -1.000000       -1.000000       -1.000000       -1.000000
# 25%          0.878350        0.784807        0.855918        0.890060
# 50%          3.096530        3.056125        3.147870        3.198935
# 75%          6.870022        6.871803        6.922042        7.038053
# max         31.020600       29.473840       30.100530       32.503680
#
#            feature_16      feature_17      feature_18      feature_19  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         4.471771        4.457114        4.484073        4.434807
# std          4.496817        4.517792        4.570285        4.536008
# min         -1.000000       -1.000000       -1.000000       -1.000000
# 25%          0.902330        0.865920        0.847498        0.862810
# 50%          3.264185        3.225160        3.213260        3.169880
# 75%          7.151950        7.132680        7.179240        7.023622
# max         32.341120       30.711720       32.124150       35.462510
#
#            feature_20      feature_21      feature_22      feature_23  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         4.376328        4.527520        4.434940        4.547066
# std          4.511171        4.565131        4.561683        4.605629
# min         -1.000000       -1.000000       -1.000000       -1.000000
# 25%          0.816200        0.921697        0.820690        0.899898
# 50%          3.089710        3.266790        3.143505        3.302525
# 75%          7.012503        7.237130        7.071372        7.213000
# max         29.863150       31.966530       30.223090       33.943460
#
#            feature_24      feature_25
# count  1000000.000000  1000000.000000
# mean         4.530857        4.660260
# std          4.577324        1.704796
# min         -1.000000       -1.000000
# 25%          0.919220        4.211470
# 50%          3.272775        4.920040
# 75%          7.182400        5.605462
# max         32.156410       11.001890

# %%
# test_data = transoform(test_data, standardization)
# test_data.describe()

# %%
from sklearn.utils import shuffle
x_data, y_data = shuffle(x_data, y_data)

# %%
# x_data = x_data[:len(x_data) // 2]
# y_data = y_data[:len(y_data) // 2]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (3000000, 26)
# (1000000, 26)
# (3000000,)
# (1000000,)

# %%
# %%time
from sklearn.naive_bayes import GaussianNB
model = classification(GaussianNB())
result = predict(model)
# Out:
# GaussianNB(priors=None)
# 0.24795466666666666
# 0.247532
# (1000000,)
# CPU times: user 14.9 s, sys: 12.8 s, total: 27.8 s
# Wall time: 38.9 s

# %%
# %%time
from sklearn.naive_bayes import GaussianNB
model = classification(GaussianNB())
result = predict(model)
# Out:
# GaussianNB(priors=None)
# 0.24791
# 0.248444
# (1000000,)
# CPU times: user 10.6 s, sys: 7.05 s, total: 17.6 s
# Wall time: 22.2 s

# %%
# %%time
from sklearn.naive_bayes import GaussianNB
model = classification(GaussianNB())
result = predict(model)
# Out:
# GaussianNB(priors=None)
# 0.2483
# 0.248675
# (1000000,)
# CPU times: user 7.46 s, sys: 2.94 s, total: 10.4 s
# Wall time: 13.2 s

# %%
# %%time
from sklearn.naive_bayes import GaussianNB
model = classification(GaussianNB())
result = predict(model)
# Out:
# GaussianNB(priors=None)
# 0.24776633333333334
# 0.248312
# (1000000,)
# CPU times: user 16.7 s, sys: 16.8 s, total: 33.5 s
# Wall time: 51.2 s

# %%
# %%time
# from sklearn import tree
# model = classification(tree.DecisionTreeClassifier())
# result = predict(model)

# %%
# %%time
# from sklearn.neighbors import KNeighborsClassifier
# model = classification(KNeighborsClassifier())
# result = predict(model)

# %%
# %%time
# from sklearn.linear_model import LogisticRegression
# model = classification(LogisticRegression())
# result = predict(model)

# %%
# %%time
# from sklearn import svm
# model = classification(svm.SVC())
# result = predict(model)

# %%
# %%time
# from sklearn.neural_network import MLPClassifier
# model = classification(MLPClassifier())
# result = predict(model)

# %%
# %%time
# from sklearn.ensemble import AdaBoostClassifier
# model = classification(AdaBoostClassifier())
# result = predict(model)

# %%
# %%time
# from sklearn.ensemble import GradientBoostingClassifier
# model = classification(GradientBoostingClassifier())
# result = predict(model)

# %%
# %%time
# from xgboost import XGBClassifier
# model = classification(XGBClassifier(n_estimators=100))
# result = predict(model)

# %%
# %%time
from sklearn.ensemble import RandomForestClassifier
model = classification(RandomForestClassifier(n_estimators=150))
result = predict(model)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=150, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# 1.0
# 0.617855
# (1000000,)
# CPU times: user 20min 50s, sys: 49.8 s, total: 21min 40s
# Wall time: 22min 53s

# %%
# %%time
from sklearn.ensemble import RandomForestClassifier
model = classification(RandomForestClassifier(n_estimators=120))
result = predict(model)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=120, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# 1.0
# 0.60298
# (1000000,)
# CPU times: user 16min 16s, sys: 33.1 s, total: 16min 49s
# Wall time: 17min 5s

# %%
# %%time
from sklearn.ensemble import RandomForestClassifier
model = classification(RandomForestClassifier(n_estimators=150))
result = predict(model)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=150, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# 1.0
# 0.671708
# (1000000,)
# CPU times: user 55min 3s, sys: 2min 4s, total: 57min 8s
# Wall time: 1h 2s

# %%
# %%time
from sklearn.ensemble import RandomForestClassifier
model = classification(RandomForestClassifier(n_estimators=150))
result = predict(model)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=150, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# 1.0
# 0.707101
# (1000000,)
# CPU times: user 2h 13min 26s, sys: 5min 36s, total: 2h 19min 2s
# Wall time: 2h 29min 38s
