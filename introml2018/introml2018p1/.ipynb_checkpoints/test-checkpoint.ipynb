# %% [markdown]
# # Part 1

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import csv

# %%
def load_data(i):
    i = str(i)
    train_data = pd.read_csv('/Users/dannyshau/.kaggle/competitions/introml2018p%s/introML2018.task%s.train.csv' % (i, i))
    test_data = pd.read_csv('/Users/dannyshau/.kaggle/competitions/introml2018p%s/introML2018.task%s.test.csv' % (i, i))
    return train_data, test_data

# %%
def standardization(series):
    from sklearn import preprocessing
    array = preprocessing.scale(series)
    series = pd.Series(array)
    return series

# %%
def normalization(series):
    from sklearn import preprocessing
    list = series.tolist()
    array = preprocessing.normalize([list])
    return pd.Series(array[0])

# %%
def transoform(data, function):
    df = pd.DataFrame()
    for i in range(data.shape[1]):
        feature = 'feature_' + str(i)
        series = pd.DataFrame(function(data[feature]), columns=[feature])
        df = pd.concat([df, series], axis=1)
    return df

# %%
def classification(model):
    print(model)
    model.fit(x_train, y_train)
    print(model.score(x_train, y_train))
    y_model = model.predict(x_test)
    from sklearn.metrics import accuracy_score
    print(accuracy_score(y_test, y_model))
    return model

# %%
def predict(model):
    result = model.predict(test_data)
    file_name = 'result.csv'
    with open(file_name, 'w', newline='') as csvfile:
        fieldnames = ['ID', 'label']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for i, j in enumerate(result):
            writer.writerow({'ID': i+1, 'label': j})
    return result

# %%
all_data = load_data(1)
train_data = all_data[0]
test_data = all_data[1]
train_data.describe()
# Out:
#           feature_0     feature_1     feature_2     feature_3     feature_4  \
# count  1.500000e+06  1.500000e+06  1.500000e+06  1.500000e+06  1.500000e+06
# mean   2.001702e+00  1.100093e+00  9.000937e-01  9.171091e-01  5.001528e-01
# std    1.154306e+00  6.569550e-01  5.621802e-01  8.274564e-01  4.819829e-01
# min    0.000000e+00  0.000000e+00  1.000000e-05  0.000000e+00  0.000000e+00
# 25%    1.002420e+00  5.535800e-01  4.426700e-01  2.643700e-01  6.507000e-02
# 50%    2.003160e+00  1.077870e+00  8.618200e-01  5.943400e-01  3.607600e-01
# 75%    3.001262e+00  1.588180e+00  1.275150e+00  1.417990e+00  8.669600e-01
# max    4.000000e+00  4.254170e+00  4.503730e+00  5.594800e+00  3.667460e+00
#
#           feature_5     feature_6     feature_7     feature_8     feature_9  \
# count  1.500000e+06  1.500000e+06  1.500000e+06  1.500000e+06  1.500000e+06
# mean   1.166440e+00  1.049625e+00  1.149005e+00  1.133744e+00  9.672538e-01
# std    7.952274e-01  9.708558e-01  1.042751e+00  8.679536e-01  8.753788e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    5.198300e-01  2.337200e-01  2.839300e-01  4.250300e-01  3.256100e-01
# 50%    1.010370e+00  7.178400e-01  7.804250e-01  8.412900e-01  6.417900e-01
# 75%    1.760153e+00  1.727420e+00  1.872240e+00  1.808512e+00  1.352500e+00
# max    5.161740e+00  6.968300e+00  6.916090e+00  5.672750e+00  6.095550e+00
#
#            ...         feature_13    feature_14    feature_15    feature_16  \
# count      ...       1.500000e+06  1.500000e+06  1.500000e+06  1.500000e+06
# mean       ...       7.825795e-01  9.337172e-01  8.011538e-01  9.826680e-01
# std        ...       5.731306e-01  5.713130e-01  6.883541e-01  8.457430e-01
# min        ...       0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%
1.500000e+06  1.500000e+06  1.500000e+06  1.500000e+06  1.500000e+06
# mean  -1.441928e-16 -1.748504e-16 -9.424639e-17  1.148616e-15  1.018989e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.161899e+00 -1.021866e+00 -1.086978e+00 -1.261881e+00 -1.530241e+00
# 25%   -8.384677e-01 -6.725856e-01 -9.141914e-01 -8.281428e-01 -8.032333e-01
# 50%   -3.613841e-01 -3.440304e-01 -2.870284e-01 -3.678659e-01 -1.160184e-01
# 75%    7.608957e-01  1.739292e-01  8.381900e-01  7.945047e-01  6.415495e-01
# max    5.421604e+00  6.017946e+00  5.067997e+00  5.410063e+00  6.036633e+00
#
#          feature_21
# count  1.500000e+06
# mean  -2.297043e-16
# std    1.000000e+00
# min   -3.903958e+00
# 25%   -6.771267e-01
# 50%    5.628259e-02
# 75%    7.097428e-01
# max    4.160573e+00
#
# [8 rows x 22 columns]

# %%
test_data.describe()
# Out:
#            feature_0      feature_1      feature_2      feature_3  \
# count  375000.000000  375000.000000  375000.000000  375000.000000
# mean        2.000707       1.099022       0.898999       0.914882
# std         1.156266       0.657182       0.562460       0.826614
# min         0.000020       0.000020       0.000010       0.000000
# 25%         0.998210       0.551300       0.441015       0.262817
# 50%         2.000735       1.077710       0.860440       0.593280
# 75%         3.005005       1.587480       1.273940       1.415963
# max         4.000000       4.232820       3.752740       5.988600
#
#            feature_4      feature_5      feature_6      feature_7  \
# count  375000.000000  375000.000000  375000.000000  375000.000000
# mean        0.500893       1.166401       1.050754       1.148989
# std         0.482052       0.793911       0.971310       1.043845
# min         0.000000       0.000000       0.000010       0.000000
# 25%         0.065310       0.521017       0.234080       0.283308
# 50%         0.361870       1.010940       0.720100       0.776540
# 75%         0.868913       1.759393       1.726827       1.871860
# max         2.685530       5.023590       6.037670       6.631900
#
#            feature_8      feature_9      ...           feature_12  \
# count  375000.000000  375000.000000      ...        375000.000000
# mean        1.134370       0.965007      ...             1.600872
# std         0.868466       0.874116      ...             1.026984
# min         0.000000       0.000000      ...             0.000010
# 25%         0.424560       0.324717      ...             0.761380
# 50%         0.842945       0.640240      ...             1.479005
# 75%         1.808633       1.348853      ...             2.329830
# max         5.558290       5.919650      ...             6.230030
#
#           feature_13     feature_14     feature_15     feature_16  \
# count  375000.000000  375000.000000  375000.000000  375000.000000
# mean        0.784367       0.934612       0.800375       0.984588
# std         0.574476       0.571321       0.688286       0.845900
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.315117       0.461750       0.220450       0.274970
# 50%         0.615900       0.899665       0.554025       0.680920
# 75%         1.237192       1.344743       1.330840       1.629750
# max         3.425140       3.647050       4.255750       4.858530
#
#           feature_17     feature_18     feature_19     feature_20  \
# count  375000.000000  375000.000000  375000.000000  375000.000000
# mean        0.915508       1.198737       1.016347       1.464286
# std         0.895957       1.103751       0.805641       0.957462
# min         0.000000       0.000000       0.000000       0.000010
# 25%         0.314140       0.190670       0.350637       0.695120
# 50%         0.607350       0.879805       0.718750       1.351380
# 75%         1.069703       2.125160       1.656023       2.081065
# max         5.774590       6.146160       4.676920       6.190900
#
#           feature_21
# count  375000.000000
# mean        0.984252
# std         0.141255
# min         0.473460
# 25%         0.888868
# 50%         0.992020
# 75%         1.084450
# max         1.532340
#
# [8 rows x 22 columns]

# %%
test_data = transoform(test_data, standardization)
test_data.describe()
# Out:
#           feature_0     feature_1     feature_2     feature_3     feature_4  \
# count  3.750000e+05  3.750000e+05  3.750000e+05  3.750000e+05  3.750000e+05
# mean   7.761021e-16  5.305386e-17  3.279486e-16  3.079397e-16  3.337467e-16
# std    1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min   -1.730303e+00 -1.672297e+00 -1.598317e+00 -1.106784e+00 -1.039086e+00
# 25%   -8.670141e-01 -8.334416e-01 -8.142515e-01 -7.888391e-01 -9.036025e-01
# 50%    2.389316e-05 -3.242927e-02 -6.855357e-02 -3.890599e-01 -2.883980e-01
# 75%    8.685711e-01  7.432628e-01  6.666103e-01  6.061856e-01  7.634459e-01
# max    1.729097e+00  4.768547e+00  5.073682e+00  6.137964e+00  4.531962e+00
#
#           feature_5     feature_6     feature_7     feature_8     feature_9  \
# count  3.750000e+05  3.750000e+05  3.750000e+05  3.750000e+05  3.750000e+05
# mean   2.078953e-16 -4.117737e-16 -1.678018e-16 -5.926021e-16  1.762904e-16
# std    1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min   -1.469185e+00 -1.081783e+00 -1.100728e+00 -1.306179e+00 -1.103982e+00
# 25%   -8.129175e-01 -8.407983e-01 -8.293204e-01 -8.173161e-01 -7.325005e-01
# 50%   -1.958169e-01 -3.404216e-01 -3.568048e-01 -3.355635e-01 -3.715380e-01
# 75%    7.469250e-01  6.960439e-01  6.925091e-01  7.763848e-01  4.391253e-01
# max    4.858470e+00  5.134225e+00  5.252616e+00  5.093957e+00  5.668186e+00
#
#            ...         feature_12    feature_13    feature_14    feature_15  \
# count      ...       3.750000e+05  3.750000e+05  3.750000e+05  3.750000e+05
# mean       ...       2.334370e-16  4.654339e-16  1.436244e-16  6.053824e-17
# std        ...       1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min        ...      -1.558802e+00 -1.365363e+00 -1.635882e+00 -1.162854e+00
# 25%        ...      -8.174354e-01 -8.168320e-01 -8.276656e-01 -8.425648e-01
# 50%        ...      -1.186648e-01 -2.932540e-01 -6.116866e-02 -3.579184e-01
# 75%        ...       7.098062e-01  7.882421e-01  7.178651e-01  7.707052e-01
# max        ...       4.507535e+00  4.596845e+00  4.747669e+00  5.020266e+00
#
#          feature_16    feature_17    feature_18    feature_19    feature_20  \
# count  3.750000e+05  3.750000e+05  3.750000e+05  3.750000e+05  3.750000e+05
# mean   7.495752e-17 -4.586127e-16 -2.094491e-16  5.024958e-17  2.615555e-16
# std    1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min   -1.163954e+00 -1.021822e+00 -1.086059e+00 -1.261539e+00 -1.529333e+00
# 25%   -8.388919e-01 -6.712023e-01 -9.133113e-01 -8.263105e-01 -8.033396e-01
# 50%   -3.589884e-01 -3.439428e-01 -2.889533e-01 -3.693914e-01 -1.179225e-01
# 75%    7.626938e-01  1.721011e-01  8.393415e-01  7.939967e-01  6.441820e-01
# max    4.579674e+00  5.423351e+00  4.482378e+00  4.543681e+00  4.936614e+00
#
#          feature_21
# count  3.750000e+05
# mean   2.091952e-15
# std    1.000001e+00
# min   -3.616113e+00
# 25%   -6.752683e-01
# 50%    5.499175e-02
# 75%    7.093427e-01
# max    3.880145e+00
#
# [8 rows x 22 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1125000, 22)
# (375000, 22)
# (1125000,)
# (375000,)

# %%
# %%time
from sklearn.naive_bayes import GaussianNB
model = classification(GaussianNB())
result = predict(model)
# Out:
# GaussianNB(priors=None)
# 0.99988
# 0.999912
# CPU times: user 3.99 s, sys: 1.4 s, total: 5.39 s
# Wall time: 5.72 s

# %%
# %%time
from sklearn import tree
model = classification(tree.DecisionTreeClassifier())
result = predict(model)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# 1.0
# 0.9994426666666667
# CPU times: user 2min 24s, sys: 1.64 s, total: 2min 26s
# Wall time: 2min 28s

# %%
# %%time
from sklearn.neighbors import KNeighborsClassifier
model = classification(KNeighborsClassifier())
result = predict(model)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
# %%time
from sklearn.linear_model import LogisticRegression
model = classification(LogisticRegression())
result = predict(model)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# 0.9998453333333334
# 0.99984
# CPU times: user 43.9 s, sys: 1.09 s, total: 45 s
# Wall time: 45 s

# %%
# %%time
from sklearn import svm
model = classification(svm.SVC())
result = predict(model)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 0.9999768888888889
# 0.999968
# CPU times: user 10min 28s, sys: 20.7 s, total: 10min 49s
# Wall time: 11min 50s

# %%
# %%time
from sklearn.neural_network import MLPClassifier
model = classification(MLPClassifier())
result = predict(model)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# 0.9999795555555555
# 0.99996
# CPU times: user 1min 10s, sys: 25.6 s, total: 1min 36s
# Wall time: 1min 48s

# %%
# %%time
from sklearn.ensemble import AdaBoostClassifier
model = classification(AdaBoostClassifier())
result = predict(model)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#           learning_rate=1.0, n_estimators=50, random_state=None)
# 0.9996124444444444
# 0.9996
# CPU times: user 5min 55s, sys: 8.08 s, total: 6min 3s
# Wall time: 6min 15s

# %%
# %%time
from sklearn.ensemble import GradientBoostingClassifier
model = classification(GradientBoostingClassifier())
result = predict(model)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=None, subsample=1.0, verbose=0,
#               warm_start=False)

# %%
# %%time
from sklearn.ensemble import RandomForestClassifier
model = classification(RandomForestClassifier(n_estimators=1000))
result = predict(model)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# 1.0
# 0.9999466666666667
# CPU times: user 3h 55min 25s, sys: 1min 43s, total: 3h 57min 9s
# Wall time: 4h 3min 25s

# %%
# %%time
from xgboost import XGBClassifier
model = classification(XGBClassifier(n_estimators=100))
result = predict(model)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)
# /Users/DannyShau/anaconda/envs/py3.5/lib/python3.5/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# 0.9998977777777778
# /Users/DannyShau/anaconda/envs/py3.5/lib/python3.5/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# 0.999888
# /Users/DannyShau/anaconda/envs/py3.5/lib/python3.5/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# CPU times: user 19min 8s, sys: 13.4 s, total: 19min 21s
# Wall time: 20min 22s
