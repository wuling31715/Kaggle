# %% [markdown]
# # Part 3

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import csv

# %%
def load_data(i):
    i = str(i)
    train_data = pd.read_csv('/Users/dannyshau/.kaggle/competitions/introml2018p%s/introML2018.task%s.train.csv' % (i, i))
    test_data = pd.read_csv('/Users/dannyshau/.kaggle/competitions/introml2018p%s/introML2018.task%s.test.csv' % (i, i))
    return train_data, test_data

# %%
def standardization(series):
    from sklearn import preprocessing
    array = preprocessing.scale(series)
    series = pd.Series(array)
    return series

# %%
def normalization(series):
    from sklearn import preprocessing
    list = series.tolist()
    array = preprocessing.normalize([list])
    return pd.Series(array[0])

# %%
def transoform(data, function):
    df = pd.DataFrame()
    for i in range(data.shape[1]):
        feature = 'feature_' + str(i)
        series = pd.DataFrame(function(data[feature]), columns=[feature])
        df = pd.concat([df, series], axis=1)
    return df

# %%
def classification(model):
    print(model)
    model.fit(x_train, y_train)
    print(model.score(x_train, y_train))
    y_model = model.predict(x_test)
    from sklearn.metrics import accuracy_score
    print(accuracy_score(y_test, y_model))
    return model

# %%
def predict(model):
    result = model.predict(test_data)
    file_name = 'result.csv'
    with open(file_name, 'w', newline='') as csvfile:
        fieldnames = ['ID', 'label']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for i, j in enumerate(result):
            writer.writerow({'ID': i+1, 'label': j})
    return result

# %%
all_data = load_data(3)
train_data = all_data[0]
test_data = all_data[1]
train_data.describe()
# Out:
#           feature_0     feature_1     feature_2     feature_3     feature_4  \
# count  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06
# mean   8.797082e-01  8.803408e-01  8.804840e-01  4.299092e+00  4.532175e+00
# std    7.344888e-01  7.339765e-01  7.339722e-01  4.371111e+00  4.456453e+00
# min   -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00
# 25%    4.038600e-01  4.046300e-01  4.043000e-01  7.874700e-01  8.868300e-01
# 50%    9.359600e-01  9.366400e-01  9.369200e-01  2.871280e+00  3.257985e+00
# 75%    1.468410e+00  1.468420e+00  1.468650e+00  6.981342e+00  7.245813e+00
# max    2.000000e+00  2.000000e+00  2.000000e+00  3.586104e+01  3.966002e+01
#
#           feature_5     feature_6     feature_7     feature_8     feature_9  \
# count  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06
# mean   4.185724e+00  5.134888e+00  4.516203e+00  4.379566e+00  4.210815e+00
# std    4.352642e+00  4.648029e+00  4.597903e+00  4.449355e+00  4.300256e+00
# min   -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00
# 25%    8.676900e-01  1.349560e+00  9.403300e-01  9.912400e-01  8.967900e-01
# 50%    2.747270e+00  3.989850e+00  2.949615e+00  3.044750e+00  2.986270e+00
# 75%    6.383492e+00  8.153290e+00  7.229020e+00  6.691190e+00  6.426843e+00
# max    3.200105e+01  3.965611e+01  3.516411e+01  3.405230e+01  3.455605e+01
#
#            ...         feature_15    feature_16    feature_17    feature_18  \
# count      ...       4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06
# mean       ...       4.854101e+00  5.767598e+00  4.238661e+00  4.798644e+00
# std        ...       4.444389e+00  4.781988e+00  4.164407e+00  4.575945e+00
# min        ...      -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00
# 25%        ...       1.176750e+00  1.842577e+00  8.266800e-01  1.070820e+00
# 50%        ...       3.908815e+00  4.930490e+00  3.116420e+00  3.606695e+00
# 75%        ...       7.578080e+00  9.027380e+00  6.776120e+00  7.542022e+00
# max        ...       3.522816e+01  3.448244e+01  3.555211e+01  3.508276e+01
#
#          feature_19    feature_20    feature_21    feature_22    feature_23  \
# count  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06
# mean   4.937496e+00  4.999786e+00  5.401784e+00  4.792201e+00  4.702564e+00
# std    4.458025e+00  4.525689e+00  4.540766e+00  4.490587e+00  1.737004e+00
# min   -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00
# 25%    1.421810e+00  1.314190e+00  1.767740e+00  1.089427e+00  4.194420e+00
# 50%    3.945485e+00  3.970240e+00  4.565500e+00  3.713645e+00  4.915800e+00
# 75%    7.576735e+00  7.853753e+00  8.235970e+00  7.586963e+00  5.700510e+00
# max    3.341408e+01  3.382314e+01  3.367309e+01  3.394698e+01  9.539610e+00
#
#               label
# count  4.000000e+06
# mean   2.000000e+00
# std    1.414214e+00
# min    0.000000e+00
# 25%    1.000000e+00
# 50%    2.000000e+00
# 75%    3.000000e+00
# max    4.000000e+00
#
# [8 rows x 25 columns]

# %%
x_data = train_data.drop('label', axis=1)
y_data = train_data['label']
x_data.describe()
# Out:
#           feature_0     feature_1     feature_2     feature_3     feature_4  \
# count  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06
# mean   8.797082e-01  8.803408e-01  8.804840e-01  4.299092e+00  4.532175e+00
# std    7.344888e-01  7.339765e-01  7.339722e-01  4.371111e+00  4.456453e+00
# min   -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00
# 25%    4.038600e-01  4.046300e-01  4.043000e-01  7.874700e-01  8.868300e-01
# 50%    9.359600e-01  9.366400e-01  9.369200e-01  2.871280e+00  3.257985e+00
# 75%    1.468410e+00  1.468420e+00  1.468650e+00  6.981342e+00  7.245813e+00
# max    2.000000e+00  2.000000e+00  2.000000e+00  3.586104e+01  3.966002e+01
#
#           feature_5     feature_6     feature_7     feature_8     feature_9  \
# count  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06
# mean   4.185724e+00  5.134888e+00  4.516203e+00  4.379566e+00  4.210815e+00
# std    4.352642e+00  4.648029e+00  4.597903e+00  4.449355e+00  4.300256e+00
# min   -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00
# 25%    8.676900e-01  1.349560e+00  9.403300e-01  9.912400e-01  8.967900e-01
# 50%    2.747270e+00  3.989850e+00  2.949615e+00  3.044750e+00  2.986270e+00
# 75%    6.383492e+00  8.153290e+00  7.229020e+00  6.691190e+00  6.426843e+00
# max    3.200105e+01  3.965611e+01  3.516411e+01  3.405230e+01  3.455605e+01
#
#            ...         feature_14    feature_15    feature_16    feature_17  \
# count      ...       4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06
# mean       ...       4.641871e+00  4.854101e+00  5.767598e+00  4.238661e+00
# std        ...       4.477075e+00  4.444389e+00  4.781988e+00  4.164407e+00
# min        ...      -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00
# 25%        ...       9.149700e-01  1.176750e+00  1.842577e+00  8.266800e-01
# 50%        ...       3.476200e+00  3.908815e+00  4.930490e+00  3.116420e+00
# 75%        ...       7.549810e+00  7.578080e+00  9.027380e+00  6.776120e+00
# max        ...       3.366432e+01  3.522816e+01  3.448244e+01  3.555211e+01
#
#          feature_18    feature_19    feature_20    feature_21    feature_22  \
# count  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06
# mean   4.798644e+00  4.937496e+00  4.999786e+00  5.401784e+00  4.792201e+00
# std    4.575945e+00  4.458025e+00  4.525689e+00  4.540766e+00  4.490587e+00
# min   -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00
# 25%    1.070820e+00  1.421810e+00  1.314190e+00  1.767740e+00  1.089427e+00
# 50%    3.606695e+00  3.945485e+00  3.970240e+00  4.565500e+00  3.713645e+00
# 75%    7.542022e+00  7.576735e+00  7.853753e+00  8.235970e+00  7.586963e+00
# max    3.508276e+01  3.341408e+01  3.382314e+01  3.367309e+01  3.394698e+01
#
#          feature_23
# count  4.000000e+06
# mean   4.702564e+00
# std    1.737004e+00
# min   -1.000000e+00
# 25%    4.194420e+00
# 50%    4.915800e+00
# 75%    5.700510e+00
# max    9.539610e+00
#
# [8 rows x 24 columns]

# %%
x_data = transoform(x_data, standardization)
x_data.describe()

# %%
test_data.describe()

# %%
test_data = transoform(test_data, standardization)
test_data.describe()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

# %%
# %%time
from sklearn.naive_bayes import GaussianNB
model = classification(GaussianNB())
result = predict(model)
# Out:
# GaussianNB(priors=None)
# 0.47515633333333335
# 0.475518
# CPU times: user 16.9 s, sys: 19 s, total: 35.9 s
# Wall time: 55.2 s

# %%
# %%time
from sklearn import tree
model = classification(tree.DecisionTreeClassifier())
result = predict(model)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# 1.0
# 0.9994426666666667
# CPU times: user 2min 24s, sys: 1.64 s, total: 2min 26s
# Wall time: 2min 28s

# %%
# %%time
from sklearn.neighbors import KNeighborsClassifier
model = classification(KNeighborsClassifier())
result = predict(model)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
# %%time
from sklearn.linear_model import LogisticRegression
model = classification(LogisticRegression())
result = predict(model)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# 0.9998453333333334
# 0.99984
# CPU times: user 43.9 s, sys: 1.09 s, total: 45 s
# Wall time: 45 s

# %%
# %%time
from sklearn import svm
model = classification(svm.SVC())
result = predict(model)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# 0.9999146666666666
# 0.9999146666666666
# CPU times: user 9min 32s, sys: 6.59 s, total: 9min 38s
# Wall time: 10min 22s

# %%
# %%time
from sklearn.neural_network import MLPClassifier
model = classification(MLPClassifier())
result = predict(model)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)
# 0.9999848888888889
# 0.9999653333333334
# CPU times: user 45.4 s, sys: 8.44 s, total: 53.8 s
# Wall time: 45.8 s

# %%
# %%time
from sklearn.ensemble import AdaBoostClassifier
model = classification(AdaBoostClassifier())
result = predict(model)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#           learning_rate=1.0, n_estimators=50, random_state=None)
# 0.999210666667
# 0.999178666667

# %%
# %%time
from sklearn.ensemble import GradientBoostingClassifier
model = classification(GradientBoostingClassifier())
result = predict(model)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=None, subsample=1.0, verbose=0,
#               warm_start=False)

# %%
# %%time
from sklearn.ensemble import RandomForestClassifier
model = classification(RandomForestClassifier(n_estimators=100))
result = predict(model)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
# %%time
from xgboost import XGBClassifier
model = classification(XGBClassifier(n_estimators=100))
result = predict(model)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)
# /Users/DannyShau/anaconda/envs/py3.5/lib/python3.5/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# 0.9998977777777778
# /Users/DannyShau/anaconda/envs/py3.5/lib/python3.5/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# 0.999888
# /Users/DannyShau/anaconda/envs/py3.5/lib/python3.5/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# CPU times: user 19min 8s, sys: 13.4 s, total: 19min 21s
# Wall time: 20min 22s
