# %% [markdown]
# # Part 3

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import csv
import datetime

# %%
pd.set_option('display.max_columns', None)

# %%
def load_data(i):
    i = str(i)
    train_data = pd.read_csv('/Users/dannyshau/.kaggle/competitions/introml2018p%s/introML2018.task%s.train.csv' % (i, i))
    test_data = pd.read_csv('/Users/dannyshau/.kaggle/competitions/introml2018p%s/introML2018.task%s.test.csv' % (i, i))
    return train_data, test_data

# %%
def standardization(series):
    from sklearn import preprocessing
    array = preprocessing.scale(series)
    series = pd.Series(array)
    return series

# %%
def normalization(series):
    from sklearn import preprocessing
    list = series.tolist()
    array = preprocessing.normalize([list])
    return pd.Series(array[0])

# %%
def transoform(data, function):
    df = pd.DataFrame()
    for i in range(data.shape[1]):
        feature = 'feature_' + str(i)
        series = pd.DataFrame(function(data[feature]), columns=[feature])
        df = pd.concat([df, series], axis=1)
    return df

# %%
def classification(model):
    print(model)
    model.fit(x_train, y_train)
    print(model.score(x_train, y_train))
    y_model = model.predict(x_test)
    from sklearn.metrics import accuracy_score
    print(accuracy_score(y_test, y_model))
    return model

# %%
def predict(model):
    result = model.predict(test_data)
    time = datetime.datetime.now().strftime("%Y%m%d%H%M%S")
    path = 'results/' + time + '.csv'
    with open(path, 'w', newline='') as csvfile:
        fieldnames = ['ID', 'label']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for i, j in enumerate(result):
            writer.writerow({'ID': i+1, 'label': j})
    print(result.shape)
    return result

# %%
all_data = load_data(3)

# %%
train_data = all_data[0]
train_data.describe()
# Out:
#           feature_0     feature_1     feature_2     feature_3     feature_4  \
# count  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06
# mean   8.797082e-01  8.803408e-01  8.804840e-01  4.299092e+00  4.532175e+00
# std    7.344888e-01  7.339765e-01  7.339722e-01  4.371111e+00  4.456453e+00
# min   -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00
# 25%    4.038600e-01  4.046300e-01  4.043000e-01  7.874700e-01  8.868300e-01
# 50%    9.359600e-01  9.366400e-01  9.369200e-01  2.871280e+00  3.257985e+00
# 75%    1.468410e+00  1.468420e+00  1.468650e+00  6.981342e+00  7.245813e+00
# max    2.000000e+00  2.000000e+00  2.000000e+00  3.586104e+01  3.966002e+01
#
#           feature_5     feature_6     feature_7     feature_8     feature_9  \
# count  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06
# mean   4.185724e+00  5.134888e+00  4.516203e+00  4.379566e+00  4.210815e+00
# std    4.352642e+00  4.648029e+00  4.597903e+00  4.449355e+00  4.300256e+00
# min   -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00
# 25%    8.676900e-01  1.349560e+00  9.403300e-01  9.912400e-01  8.967900e-01
# 50%    2.747270e+00  3.989850e+00  2.949615e+00  3.044750e+00  2.986270e+00
# 75%    6.383492e+00  8.153290e+00  7.229020e+00  6.691190e+00  6.426843e+00
# max    3.200105e+01  3.965611e+01  3.516411e+01  3.405230e+01  3.455605e+01
#
#          feature_10    feature_11    feature_12    feature_13    feature_14  \
# count  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06
# mean   5.127783e+00  4.430754e+00  4.588406e+00  5.180442e+00  4.641871e+00
# std    4.764092e+00  4.741519e+00  4.498950e+00  4.522238e+00  4.477075e+00
# min   -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00
# 25%    1.173767e+00  5.160300e-01  1.108700e+00  1.510890e+00  9.149700e-01
# 50%    3.915265e+00  2.948305e+00  3.202110e+00  4.147615e+00  3.476200e+00
# 75%    8.088430e+00  7.330872e+00  7.084780e+00  8.193730e+00  7.549810e+00
# max    3.299194e+01  3.224919e+01  3.300637e+01  3.509447e+01  3.366432e+01
#
#          feature_15    feature_16    feature_17    feature_18    feature_19  \
# count  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06
# mean   4.854101e+00  5.767598e+00  4.238661e+00  4.798644e+00  4.937496e+00
# std    4.444389e+00  4.781988e+00  4.164407e+00  4.575945e+00  4.458025e+00
# min   -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00
# 25%    1.176750e+00  1.842577e+00  8.266800e-01  1.070820e+00  1.421810e+00
# 50%    3.908815e+00  4.930490e+00  3.116420e+00  3.606695e+00  3.945485e+00
# 75%    7.578080e+00  9.027380e+00  6.776120e+00  7.542022e+00  7.576735e+00
# max    3.522816e+01  3.448244e+01  3.555211e+01  3.508276e+01  3.341408e+01
#
#          feature_20    feature_21    feature_22    feature_23         label
# count  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06  4.000000e+06
# mean   4.999786e+00  5.401784e+00  4.792201e+00  4.702564e+00  2.000000e+00
# std    4.525689e+00  4.540766e+00  4.490587e+00  1.737004e+00  1.414214e+00
# min   -1.000000e+00 -1.000000e+00 -1.000000e+00 -1.000000e+00  0.000000e+00
# 25%    1.314190e+00  1.767740e+00  1.089427e+00  4.194420e+00  1.000000e+00
# 50%    3.970240e+00  4.565500e+00  3.713645e+00  4.915800e+00  2.000000e+00
# 75%    7.853753e+00  8.235970e+00  7.586963e+00  5.700510e+00  3.000000e+00
# max    3.382314e+01  3.367309e+01  3.394698e+01  9.539610e+00  4.000000e+00

# %%
x_data = train_data.drop('label', axis=1)
y_data = train_data['label']
# x_data.describe()

# %%
# x_data = transoform(x_data, standardization)
# x_data.describe()

# %%
test_data = all_data[1]
test_data.describe()
# Out:
#             feature_0       feature_1       feature_2       feature_3  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         0.881194        0.879729        0.880528        4.303223
# std          0.733726        0.733778        0.733561        4.371599
# min         -1.000000       -1.000000       -1.000000       -1.000000
# 25%          0.406230        0.404320        0.404610        0.789050
# 50%          0.938415        0.936340        0.935620        2.879995
# 75%          1.469010        1.466760        1.468650        6.987497
# max          2.000000        2.000000        2.000000       34.799050
#
#             feature_4       feature_5       feature_6       feature_7  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         4.528493        4.188811        5.137291        4.516769
# std          4.449263        4.352495        4.653121        4.599910
# min         -1.000000       -1.000000       -1.000000       -1.000000
# 25%          0.885237        0.869677        1.347948        0.942090
# 50%          3.260115        2.752300        3.991820        2.944905
# 75%          7.230557        6.390840        8.151930        7.221425
# max         30.486370       32.574810       31.757400       34.200340
#
#             feature_8       feature_9      feature_10      feature_11  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         4.380492        4.207599        5.130168        4.431730
# std          4.448617        4.295514        4.764020        4.738423
# min         -1.000000       -1.000000       -1.000000       -1.000000
# 25%          0.990128        0.898360        1.176020        0.517208
# 50%          3.049585        2.986155        3.918230        2.958245
# 75%          6.694762        6.416552        8.095320        7.330233
# max         32.369300       28.934950       31.895920       30.506810
#
#            feature_12      feature_13      feature_14      feature_15  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         4.584965        5.182309        4.643386        4.851351
# std          4.496907        4.519490        4.474878        4.444369
# min         -1.000000       -1.000000       -1.000000       -1.000000
# 25%          1.110300        1.515237        0.916510        1.177350
# 50%          3.194360        4.152965        3.481250        3.906965
# 75%          7.072125        8.203475        7.547290        7.566488
# max         33.864510       31.176510       29.226290       30.295010
#
#            feature_16      feature_17      feature_18      feature_19  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         5.765674        4.237392        4.802302        4.940497
# std          4.782626        4.163802        4.571525        4.462734
# min         -1.000000       -1.000000       -1.000000       -1.000000
# 25%          1.842288        0.826018        1.076240        1.418695
# 50%          4.920740        3.112330        3.619190        3.950585
# 75%          9.024465        6.777692        7.546267        7.580607
# max         31.782730       32.408160       37.582510       35.575820
#
#            feature_20      feature_21      feature_22      feature_23
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean         4.996585        5.403867        4.790798        4.703005
# std          4.530460        4.541097        4.491916        1.735208
# min         -1.000000       -1.000000       -1.000000       -1.000000
# 25%          1.306227        1.769297        1.084427        4.193220
# 50%          3.963120        4.566010        3.710775        4.915565
# 75%          7.859563        8.241800        7.587542        5.700743
# max         31.433140       33.804930       35.484500        9.467120

# %%
# test_data = transoform(test_data, standardization)
# test_data.describe()

# %%
from sklearn.utils import shuffle
x_data, y_data = shuffle(x_data, y_data)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (3000000, 24)
# (1000000, 24)
# (3000000,)
# (1000000,)

# %%
# %%time
from sklearn.naive_bayes import GaussianNB
model = classification(GaussianNB())
result = predict(model)
# Out:
# GaussianNB(priors=None)
# 0.475172
# 0.475878
# (1000000,)
# CPU times: user 15.8 s, sys: 14.2 s, total: 29.9 s
# Wall time: 49.3 s

# %%
# %%time
# from sklearn import tree
# model = classification(tree.DecisionTreeClassifier())
# result = predict(model)

# %%
# %%time
# from sklearn.neighbors import KNeighborsClassifier
# model = classification(KNeighborsClassifier())
# result = predict(model)

# %%
# %%time
# from sklearn.linear_model import LogisticRegression
# model = classification(LogisticRegression())
# result = predict(model)

# %%
# %%time
# from sklearn import svm
# model = classification(svm.SVC())
# result = predict(model)

# %%
# %%time
# from sklearn.neural_network import MLPClassifier
# model = classification(MLPClassifier())
# result = predict(model)

# %%
# %%time
# from sklearn.ensemble import AdaBoostClassifier
# model = classification(AdaBoostClassifier())
# result = predict(model)

# %%
# %%time
# from sklearn.ensemble import GradientBoostingClassifier
# model = classification(GradientBoostingClassifier())
# result = predict(model)

# %%
# %%time
# from xgboost import XGBClassifier
# model = classification(XGBClassifier(n_estimators=100))
# result = predict(model)

# %%
# %%time
from sklearn.ensemble import RandomForestClassifier
model = classification(RandomForestClassifier(n_estimators=100))
result = predict(model)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# 1.0
# 0.976666
# CPU times: user 1h 21min 13s, sys: 2min 23s, total: 1h 23min 37s
# Wall time: 1h 30min 4s

# %%
# %%time
from sklearn.ensemble import RandomForestClassifier
model = classification(RandomForestClassifier(n_estimators=150))
result = predict(model)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=150, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# 1.0
# 0.977173
# (1000000,)
# CPU times: user 1h 54min 15s, sys: 2min 52s, total: 1h 57min 8s
# Wall time: 2h 2min 58s
